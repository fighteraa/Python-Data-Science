# %% [markdown]
# ### Задание:
# Используя данные из train.csv, построить модель для предсказания цен на недвижимость (квартиры).
# С помощью полученной модели предсказать цены для квартир из файла test.csv.
#
# Целевая переменная:
# Price
#
# Основная метрика:
# R2 - коэффициент детерминации (sklearn.metrics.r2_score)
#
# Вспомогательная метрика:
# MSE - средняя квадратичная ошибка (sklearn.metrics.mean_squared_error)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = 100

# %matplotlib inline

# %config InlineBackend.figure_format = 'svg'

# %%
# Загружаем данные
data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')

# %% [markdown]
# ### Data exploration and clear data

# %%
data_train.info()
# Видим, что есть пропущеные значения LifeSquare и Healthcare_1.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
data_test.info()
# Видим, аналогичную ситуацию с признаками LifeSquare и Healthcare_1,
# как в тренировочном датасете
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
# Id               5000 non-null int64
# DistrictId       5000 non-null int64
# Rooms            5000 non-null float64
# Square           5000 non-null float64
# LifeSquare       3959 non-null float64
# KitchenSquare    5000 non-null float64
# Floor            5000 non-null int64
# HouseFloor       5000 non-null float64
# HouseYear        5000 non-null int64
# Ecology_1        5000 non-null float64
# Ecology_2        5000 non-null object
# Ecology_3        5000 non-null object
# Social_1         5000 non-null int64
# Social_2         5000 non-null int64
# Social_3         5000 non-null int64
# Healthcare_1     2623 non-null float64
# Helthcare_2      5000 non-null int64
# Shops_1          5000 non-null int64
# Shops_2          5000 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 742.3+ KB

# %%
data_train.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
# ...

# %%
data_test.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    725          58    2.0  49.882643   33.432782            6.0      6
# 1  15856          74    2.0  69.263183         NaN            1.0      6
# 2   5480         190    1.0  13.597819   15.948246           12.0      2
# 3  15664          47    2.0  73.046609   51.940842            9.0     22
# 4  14275          27    1.0  47.527111   43.387569            1.0     17
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        14.0       1972   0.310199         B         B        11      2748
# 1         1.0       1977   0.075779         B         B         6      1437
# 2         5.0       1909   0.000000         B         B        30      7538
# 3        22.0       2007   0.101872         B         B        23      4583
# 4        17.0       2017   0.072158         B         B         2       629
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# ...

# %%
data_train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %% [markdown]
# Из описания видно, что Rooms, Square, LifeSquare, KitchenSquare, HouseFloor содержат максимальные значения, которые
# возможно, являются выборосами, т.к. они физически невозможны.
#
# Рассмотрим каждый признка по отдельности.
#
# Id - Id квартиры. Это уникальный идентификатор.

# %%
data_train['Id'].nunique()
# Out:
# 10000

# %%
data_test['Id'].nunique()
# Out:
# 5000

# %%
# DistrictId - Id района. 
plt.hist(data_train['DistrictId'], bins=30);

# %%
plt.hist(data_test['DistrictId'], bins=30);

# %% [markdown]
# Видим, что распределения DistrictId похожи, и т.к. у нас нет информации о номерах районов
# оставляем их без изменений.
# Rooms - количество комнат.
# Проверим их на отклонения, проверив, есть ли квартиры с количеством комнат больше 5,
# либо равных 0.
# Проверим это условие в 2-х датасетах.

# %% [markdown]
# ### Clear Rooms

# %%
data_train.loc[((data_train['Rooms'] > 5) | (data_train['Rooms'] == 0)), :]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0   59.056975   36.223072           10.0     22
# 1397  12638          27    0.0  138.427694  136.215499            0.0      4
# 1454   8491           1   19.0   42.006046   21.779288            7.0     17
# 1981   7917          27    0.0  212.932361  211.231125            0.0      2
# 2170  14003          99    6.0   59.414334   38.702244            6.0      7
# 2269   7317          27    0.0   41.790881         NaN            0.0     13
# 3911    770          28    0.0   49.483501         NaN            0.0     16
# 4366    456           6    0.0   81.491446         NaN            0.0      4
# 4853   3224          27    0.0    2.377248    0.873147            0.0      1
# 6149   3159          88    0.0   38.697117   19.345131            9.0      9
# 8834   9443          27    0.0   87.762616   85.125471            0.0      5
# ...

# %%
data_test.loc[((data_test['Rooms'] > 5) | (data_test['Rooms'] == 0)), :]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2071  10793          23    6.0  110.750226         NaN            0.0      2
# 2406   3343          58    0.0  116.824201  113.692424            0.0      3
# 2524  10729          27    0.0   76.345154   42.820796           12.0     14
# 3217   4058          27    6.0  223.453689  104.113552           16.0      2
# 3398   1435         111   17.0   52.866107   32.528342            8.0     15
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2071         2.0       2015   0.014073         B         B         2
# 2406         3.0       1977   0.437885         B         B        23
# 2524         0.0       1977   0.017647         B         B         2
# 3217         2.0       2017   0.041116         B         B        53
# 3398        17.0       1987   0.093443         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# ...

# %% [markdown]
# Видим, что есть выбросы. Первое, что приходит в голову то изменить значения выбросов в соответствии
# с средней площадью комнат, но есть квартиры с c Id:3159, 3224 у которых нам будетс сложно подобрать через
# среднюю площадь значения, потому будем их исправлять в ручную.
#
# Посмотримзначения медиан площадей, в зависимости от количества комнат.

# %%
data_median_square = data_train.groupby(['Rooms'], as_index=False)[['Square']].median().\
                                        rename(columns={'Square': 'median_square'})
data_median_square
# Out:
#    Rooms  median_square
# 0    0.0      65.487474
# 1    1.0      40.406590
# 2    2.0      55.841812
# 3    3.0      77.413643
# 4    4.0      98.668054
# 5    5.0     116.084861
# 6    6.0      59.414334
# 7   10.0      59.964120
# 8   19.0      42.006046

# %% [markdown]
# ???????????????????????????формулировка.
#
# Напишем функцию, которая будет проверять, если квартиры в которых клоичество комнат
# больше 5 или равно 0, то смотрим диапазон м/д медианами площадей для количества комнат,
# и если площадь попадает в диапазон, то меняем значение количества комнат.

# %%
def clear_rooms(df, source_df):
    mean_square = source_df.groupby('Rooms', as_index=False)[['Square']].median().\
                                    rename(columns={'Square': 'median_square'})
    
    for i in range(1, 5): 
        df.loc[(~df.Rooms.between(1,5)) & 
                       (df.Square > mean_square.loc[mean_square.Rooms==i, 'median_square'].values[0]) & 
                       (df.Square <= mean_square.loc[mean_square.Rooms==i+1, 'median_square'].values[0]), 'Rooms'] = i
    df.loc[(df.Square > mean_square.loc[mean_square.Rooms==i+1, 'median_square'].values[0]), 'Rooms'] = 5

    return df

# %%
data_train = clear_rooms(data_train, data_train)

# %%
data_test = clear_rooms(data_test, data_train)

# %%
data_train.loc[((data_train['Rooms'] > 5) | (data_train['Rooms'] == 0)), :]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4853  3224          27    0.0   2.377248    0.873147            0.0      1
# 6149  3159          88    0.0  38.697117   19.345131            9.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4853         0.0       1977   0.017647         B         B         2
# 6149        16.0       1982   0.127376         B         B        43
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4853       469         0           NaN            0        0       B
# 6149      8429         3           NaN            3        9       B
#
#               Price
# 4853  126596.941798
# 6149  158998.110646

# %%
data_test.loc[((data_test['Rooms'] > 5) | (data_test['Rooms'] == 0)), :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %% [markdown]
# Квартиры, у которых по площади мы не можем определить, заполним вручную.
# Квартиры с Id 3159, похожа на однокомнатную квартиру.

# %%
data_train.loc[data_train['Id'] == 3159, 'Rooms'] = 1

# %% [markdown]
# Найдем среднее значение комнат по району и году постройки, округлим это значение
# и заполним им значение количества комнтат для квартиры с Id 3224

# %%
data_median_rooms = data_train.groupby(['DistrictId', 'HouseYear'], as_index=False)[['Rooms']].mean().rename(columns={'Rooms': 'mean_rooms'})
data_median_rooms.loc[((data_median_rooms['DistrictId'] == 27) & (data_median_rooms['HouseYear'] == 1977)), :]
# Out:
#      DistrictId  HouseYear  mean_rooms
# 695          27       1977    1.783333

# %%
data_train.loc[data_train['Id'] == 3224, 'Rooms'] = 2

# %% [markdown]
# ### Clear Square, LifeSquare, KitchenSquare

# %%
sns.boxplot(data_train['Square']);

# %%
sns.boxplot(data_train['LifeSquare']);

# %%
sns.boxplot(data_train['KitchenSquare']);

# %%
sns.boxplot(data_test['Square']);

# %%
sns.boxplot(data_test['LifeSquare']);

# %%
sns.boxplot(data_test['KitchenSquare']);

# %% [markdown]
# Изучив графики, напишем функцию, которая будет принимать на вход наши данные и если
# значения в столбце будет меньше, или больше, чем это возможно, то мы будем их заменять
# медианным значением Square, в зависимости от количества комнат.
#
# Перед очисткой данных заполним столбец 'LifeSquare' 0?????? Или медианой, или средним????
#
# Цифры для порогов площадей я взял из Интернета с сайта агенства недвижимости ЦАН.
#
# ????? ВОЗМОЖНО ЕЩЕ СЮДА DISTRICT ID ПРИКРУТИТЬ?????????

# %%
data_train['LifeSquare'] = data_train['LifeSquare'].fillna(0)
data_test['LifeSquare'] = data_test['LifeSquare'].fillna(0)

# %%
def clear_square(df, source_df, name_column, min_sq, large_sq):
    median_square = source_df.groupby('Rooms', as_index=False)[[name_column]].median().rename(columns={name_column: 'median_square'})
    df = pd.merge(df, median_square, on='Rooms', how='left')
    small_square_ids_train = df.loc[df[name_column] < min_sq, 'Id'].values
    df.loc[df['Id'].isin(small_square_ids_train), name_column] = df['median_square']
    large_square_ids_train = df.loc[df[name_column] > large_sq, 'Id'].values
    df.loc[df['Id'].isin(large_square_ids_train), name_column] = df['median_square']
    df.drop('median_square', axis=1, inplace=True)
    
    return df
    
# data_train = clear_square(data_train, data_train, 'Square', 28, 150)
# data_train = clear_square(data_train, data_train, 'LifeSquare', 15, 120)
# data_train = clear_square(data_train, data_train, 'KitchenSquare', 5, 30)

# data_test = clear_square(data_test, data_train, 'Square', 28, 150)
# data_test = clear_square(data_test, data_train, 'LifeSquare', 15, 120)
# data_test = clear_square(data_test, data_train, 'KitchenSquare', 5, 30)
# data_train, data_test = clear_square(data_train, data_test, 'Square', 28, 150)
# data_train, data_test = clear_square(data_train, data_test, 'LifeSquare', 15, 120)
# data_train, data_test = clear_square(data_train, data_test, 'KitchenSquare', 5, 30)

# %%
# Подумать над функцией проверки...!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
def check_square(data_train):
    return data_train.loc[(((data_train['Square'] < 28) | (data_train['Square'] > 150))
                & ((data_train['LifeSquare'] < 15) | (data_train['LifeSquare'] > 120))
                & ((data_train['KitchenSquare'] < 5) | (data_train['KitchenSquare'] > 30))), :]
df = check_square(data_train)
df
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 501   15923          27    1.0   26.553188    0.000000            0.0     25
# 900    8940          34    1.0   26.811587    0.000000            0.0     18
# 1184   3902          23    1.0   27.442238    0.000000            1.0      4
# 1316  11526          27    1.0    4.633498    1.969969            1.0     18
# 1608  10202           6    1.0    2.596351    4.604943            1.0      3
# 1812   5602          93    5.0  169.385184    0.000000            1.0      2
# 1891  13685           0    1.0   17.498542   13.446544            0.0      7
# 1981   7917          27    5.0  212.932361  211.231125            0.0      2
# 3084   3732         112    1.0   20.213128   13.800281            3.0      5
# 3260  16204          23    5.0  160.647588    0.000000            1.0      3
# 3413   9487           5    1.0    5.129222    5.549458            1.0      1
# ...

# %% [markdown]
# Физически невозможно, чтобы жилая площадь была больше площади квартиры,
# потому если у нас встретятся такие значения мы эти значения, заменим,
# умножив их на 0.65.
# К жилой площади у нас относятся только жилые комнаты.

# %%
def clear_large_life_square(df):
    df.loc[(df['Square'] < df['LifeSquare']), 'LifeSquare' ] = df['LifeSquare'].apply(lambda x: x*0.65)
    return df

# %%
# data_train.loc[data_train['Square'] < data_train['LifeSquare']]

# %%
# data_test.loc[data_test['Square'] < data_test['LifeSquare']]

# %%
# Функция, как заменить данные, где жилая пложащь больще площади самой вартиры.
# data_train.loc[(data_train['Square'] < data_train['LifeSquare']), 'LifeSquare' ] = data_train['LifeSquare']*0,7
# small_square_ids_train = data_train.loc[(data_train['Square'] < data_train['LifeSquare']) , 'Id'].values
# data_train.loc[data_train['Id'].isin(small_square_ids_train), ['LifeSquare']] = data_train['Square']
data_train.loc[(data_train['Square'] < data_train['LifeSquare']), 'LifeSquare' ] = data_train['LifeSquare'].apply(lambda x: x*0.65)
# small_square_ids_train
# small_square_ids_train = data_clr_train.loc[data_clr_train[name_column] < min_sq, 'Id'].values
#     data_clr_train.loc[data_clr_train['Id'].isin(small_square_ids_train), name_column] = data_clr_train['median_square']

# %%
data_train.loc[(data_train['Square'] < data_train['LifeSquare']), 'LifeSquare']
# Out:
# 212       43.958666
# 590      171.302313
# 1608       2.993213
# 3280      26.523794
# 4328    4862.384884
# 6332     106.699684
# 6392       2.941728
# 8030      51.849177
# 8437     299.951349
# 9294       3.417231
# Name: LifeSquare, dtype: float64

# %% [markdown]
# ### Foor and HouseFloor

# %%
sns.boxplot(data_train['Floor']);

# %%
sns.boxplot(data_test['Floor']);

# %%
sns.boxplot(data_train['HouseFloor']);

# %%
sns.boxplot(data_test['HouseFloor']);

# %% [markdown]
# Видим, что есть выбросы, посмотрим их подробнее.ё

# %%
data_train.loc[data_train['Floor'] > 48, :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
data_test.loc[data_test['Floor'] > 48, :]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4698  15759          17    2.0  57.60187   37.744743           10.0     78
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4698        22.0       1989        0.0         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4698      5027         4          46.0            1        1       B

# %%
data_train.loc[data_train['HouseFloor'] > 48, :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 6131  10806           5    1.0  51.944587   48.709601            1.0      6
# 8599   9300          74    2.0  71.747869   48.476876            9.0      5
# 8854     78          30    2.0  65.773749   43.427663            1.0      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6131        99.0       1977   0.150818         B         B        16
# 8599        99.0       1977   0.075779         B         B         6
# 8854       117.0       1977   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 6131      3433         4        2643.0            4        5       B
# 8599      1437         3           NaN            0        2       B
# 8854      6398       141        1046.0            3       23       B
#
#               Price
# 6131  296127.115515
# 8599  243329.912579
# 8854  207248.370520

# %%
data_test.loc[data_test['HouseFloor'] > 48, :]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 651  15864          27    3.0  47.722835   47.098813            9.0     18
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 651        99.0       1977   0.072158         B         B         2       629
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 651         1           NaN            0        0       A

# %% [markdown]
# Видим, что есть небольшое количество выбросов, поэтому исправим их вручную

# %%
data_train.loc[data_train['Id'] == 15759, 'Floor'] = 18
data_train.loc[data_train['Id'].isin([10806, 9300]), 'HouseFloor'] = 9
data_train.loc[data_train['Id'] == 78, 'HouseFloor'] = 17

# %% [markdown]
# Найдем максимальное значение HouseFloor по году и району и заполним этим значением
# выбоброс поле HouseFloor в датасете test

# %%
data_stat1 = data_train.groupby(['HouseYear', 'DistrictId'], as_index=False)[['HouseFloor']].max().\
                                rename(columns={'HouseFloor': 'HouseFloor'})
data_stat1.loc[((data_stat1['HouseYear'] == 1977) & (data_stat1['DistrictId'] == 27)), :]
# Out:
#       HouseYear  DistrictId  HouseFloor
# 1413       1977          27        25.0

# %%
data_test.loc[data_test['Id'] == 15864, 'HouseFloor'] = 17

# %% [markdown]
# ### HouseYear

# %%
data_train.loc[((data_train['HouseYear'] > 2020) & (data_train['HouseYear'] > 2020)), :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497        12.0   20052011   0.136330         B         B        30
# 4189         9.0       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1497      6141        10         262.0            3        6       B
# 4189      4756        16        2857.0            5        8       B
#
#               Price
# 1497  254084.534396
# 4189  243028.603096

# %%
data_test.loc[((data_test['HouseYear'] > 2020) & (data_test['HouseYear'] > 2020)), :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %% [markdown]
# Исправим значения вручную

# %%
data_train.loc[data_train['HouseYear'] == 20052011, 'HouseYear'] = 2008
data_train.loc[data_train['HouseYear'] == 4968, 'HouseYear'] = 1968

# %%
data_train.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
# ...

# %%
def clear_data(df, source_df, min_sq, large_sq, min_life_sq, large_life_sq, min_kitch_sq, large_kitch_sq, 
               name_column1='Square', name_column2='LifeSquare', name_column3='KitchenSquare'):
    df = clear_rooms(df, source_df)
    df = clear_square(df, source_df, name_column1, min_sq, large_sq)
    df = clear_square(df, source_df, name_column2, min_life_sq, large_life_sq)
    df = clear_square(df, source_df, name_column3, min_kitch_sq, large_kitch_sq)
    return df

# data_train = clear_square(data_train, data_train, 'Square', 28, 150)
# data_train = clear_square(data_train, data_train, 'LifeSquare', 15, 120)
# data_train = clear_square(data_train, data_train, 'KitchenSquare', 5, 30)

# def clear_data(df, source_df):
#     df = clear_rooms(df, source_df)
# #     df = clear_square(df, source_df, name_column1, min_sq, large_sq)
# #     df = clear_square(df, source_df, name_column2, min_life_sq, large_life_sq)
# #     df = clear_square(df, source_df, name_column3, min_kitch_sq, large_kitch_sq)
#     return df

# data_train = clear_square(data_train, data_train, 'Square', 28, 150)
# data_train = clear_square(data_train, data_train, 'LifeSquare', 15, 120)
# data_train = clear_square(data_train, data_train, 'KitchenSquare', 5, 30)

# %%
# data_train = clear_data(data_train, data_train, 28, 150)
# data_test = clear_data(data_test, data_train, 28, 150)

data_train = clear_data(data_train, data_train, 28, 150, 15, 120, 5, 30)
data_test = clear_data(data_test, data_train, 28, 150, 15, 120, 5, 30)

# %% [markdown]
# ### !!!!!!!! Добавить проверку, что все работает и еще подумать на счет заполнения Healthcaer_1 и LifeSquare
